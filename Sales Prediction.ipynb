# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
a=df['TV']
b=df['Sales']
plt.scatter(a, b)

# %%
a=df['TV']
b=df['Sales']
plt.scatter(a, b)
coefficients = np.polyfit(a, b, 1)
polynomial = np.poly1d(coefficients)
trendline = polynomial(a)
plt.plot(a, trendline, color='red')  # Add the trendline in red
plt.xlabel('TV')
plt.ylabel('Sales')
plt.title('Scatter plot with Best-Fit Line')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest= train_test_split(df[['TV']], df["Sales"] , train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(xtrain, ytrain)
#df.reshape(-1, 1)
# Out:
# LinearRegression()

# %%
xtrain
# Out:
#         TV
# 95   163.3
# 116  139.2
# 54   262.7
# 197  177.0
# 94   107.4
# ..     ...
# 78     5.4
# 43   206.9
# 169  284.3
# 127   80.2
# 96   197.6
#
# [160 rows x 1 columns]

# %%
ytrain
# Out:
# 95     16.9
# 116    12.2
# 54     20.2
# 197    14.8
# 94     11.5
#        ...
# 78      5.3
# 43     17.9
# 169    20.0
# 127    11.9
# 96     16.7
# Name: Sales, Length: 160, dtype: float64

# %%
len(xtest)
# Out:
# 40

# %%
model.predict(xtest)
# Out:
# array([ 8.82149991, 12.06301188, 22.58519731, 15.30452384, 16.42462745,
#        19.40591333,  8.28973355,  9.56257856, 10.47336988, 11.05605005,
#        20.4920744 , 23.34324723,  7.3959135 , 18.6535205 , 14.38241834,
#        10.5186266 , 19.19660104, 15.59303538, 12.04604061, 16.36239947,
#         9.98686023, 19.99990767, 11.66701565, 19.3153999 , 23.12262076,
#        22.61348276,  8.08042126, 16.67353937,  8.51601711,  8.25013393,
#        14.72750077, 22.21748653, 19.71705322, 10.1056591 , 12.54386444,
#        10.88633738, 21.83280448, 11.15787765, 20.27144793, 21.5160075 ])

# %%
ytest
# Out:
# 134    10.8
# 196    14.0
# 102    19.8
# 3      16.5
# 153    16.0
# 122    16.6
# 76      6.9
# 170     8.4
# 10     12.6
# 117     9.4
# 147    25.4
# 42     20.7
# 158     7.3
# 59     18.4
# 99     17.2
# 49      9.7
# 128    24.7
# 180    15.5
# 156    15.3
# 177    16.7
# 6      11.8
# 165    16.9
# 125    10.6
# 174    16.5
# 98     25.4
# 150    16.1
# 12      9.2
# 112    17.1
# 66     11.0
# 72      8.8
# 120    15.5
# 137    20.8
# 124    19.7
# 129     9.7
# 63     14.0
# 140    10.9
# 36     25.4
# 114    14.6
# 62     20.7
# 61     24.2
# Name: Sales, dtype: float64

# %%
model.score(xtest, ytest)
# Out:
# 0.7883690719820506

# %%
# Assuming model is your trained LogisticRegression model
import pickle
with open('my_model.pkl', 'wb') as file:
    pickle.dump(model, file)
